# %%
import torch

# %%
#Connecting Google Colab with Google Drive
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
#Check for GPU
gpu = torch.cuda.is_available()
device = 'cuda' if gpu == True else 'cpu'
print('Using device:', device)
# Out:
# Using device: cuda

# %%
#Directories path
train_dir = "/content/drive/MyDrive/Oranges Dataset/Train"
test_dir = "/content/drive/MyDrive/Oranges Dataset/Test"

# %%
from torchvision import transforms

# Image transformations
transforms = transforms.Compose([
        transforms.RandomResizedCrop(size=256, scale=(0.8, 1.0)),
        transforms.RandomRotation(degrees=15),
        transforms.RandomHorizontalFlip(),
        transforms.CenterCrop(size=224),  # Image net standards
        transforms.ToTensor(),
        transforms.Normalize([0.485, 0.456, 0.406],[0.229, 0.224, 0.225])  # Imagenet standards
    ])

# %%
from torchvision import datasets
from torch.utils.data import DataLoader

training_data = datasets.ImageFolder(root = train_dir, transform = transforms)
testing_data = datasets.ImageFolder(root = test_dir, transform = transforms)

train_loader = DataLoader(training_data, batch_size=32, shuffle=True)
test_loader = DataLoader(testing_data, batch_size=32, shuffle=True)

# %%
import numpy as np
import pandas as pd
from PIL import Image
import matplotlib.pyplot as plt
import os

def imshow(img):
    #img = img / 2 + 0.5  # unnormalize
    plt.imshow(np.transpose(img, (1, 2, 0)))  # convert from Tensor image
# obtain one batch of training images
data_iter = iter(train_loader)
images, lbls = data_iter.next()
images = images.numpy() # convert images to numpy for display
# plot the images in the batch, along with the corresponding labels
fig = plt.figure(figsize=(10, 4))
# display 20 images
for idx in np.arange(10):
    ax = fig.add_subplot(2, 10/2, idx+1, xticks=[], yticks=[])
    imshow(images[idx])
    label = lbls[idx]
    #ax.set_title(classes[label])
    #ax.set_title(classes[lbls[idx]])
print('Training set size: ', len(training_data))
print('Test set size: ', len(testing_data))
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Training set size:  321
# Test set size:  80

# %%
# Iterate through the dataloader once
train_iter = iter(train_loader)
features, labels = next(train_iter)
features.shape, labels.shape
# Out:
# (torch.Size([32, 3, 224, 224]), torch.Size([32]))

# %%
#Loading in a pre-trained model
from torchvision import models
model = models.googlenet(pretrained=True)

# %%
# Freeze model weights
for param in model.parameters():
    param.requires_grad = False

model.eval()
# Out:
# GoogLeNet(
#   (conv1): BasicConv2d(
#     (conv): Conv2d(3, 64, kernel_size=(7, 7), stride=(2, 2), padding=(3, 3), bias=False)
#     (bn): BatchNorm2d(64, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#   )
#   (maxpool1): MaxPool2d(kernel_size=3, stride=2, padding=0, dilation=1, ceil_mode=True)
#   (conv2): BasicConv2d(
#     (conv): Conv2d(64, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#     (bn): BatchNorm2d(64, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#   )
#   (conv3): BasicConv2d(
#     (conv): Conv2d(64, 192, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#     (bn): BatchNorm2d(192, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#   )
#   (maxpool2): MaxPool2d(kernel_size=3, stride=2, padding=0, dilation=1, ceil_mode=True)
#   (inception3a): Inception(
#     (branch1): BasicConv2d(
#       (conv): Conv2d(192, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn): BatchNorm2d(64, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (branch2): Sequential(
#       (0): BasicConv2d(
#         (conv): Conv2d(192, 96, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn): BatchNorm2d(96, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#       )
#       (1): BasicConv2d(
#         (conv): Conv2d(96, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn): BatchNorm2d(128, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (branch3): Sequential(
#       (0): BasicConv2d(
#         (conv): Conv2d(192, 16, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn): BatchNorm2d(16, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#       )
#       (1): BasicConv2d(
#         (conv): Conv2d(16, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn): BatchNorm2d(32, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (branch4): Sequential(
#       (0): MaxPool2d(kernel_size=3, stride=1, padding=1, dilation=1, ceil_mode=True)
#       (1): BasicConv2d(
#         (conv): Conv2d(192, 32, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn): BatchNorm2d(32, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#   )
#   (inception3b): Inception(
#     (branch1): BasicConv2d(
#       (conv): Conv2d(256, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn): BatchNorm2d(128, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (branch2): Sequential(
#       (0): BasicConv2d(
#         (conv): Conv2d(256, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn): BatchNorm2d(128, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#       )
#       (1): BasicConv2d(
#         (conv): Conv2d(128, 192, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn): BatchNorm2d(192, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (branch3): Sequential(
#       (0): BasicConv2d(
#         (conv): Conv2d(256, 32, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn): BatchNorm2d(32, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#       )
#       (1): BasicConv2d(
#         (conv): Conv2d(32, 96, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn): BatchNorm2d(96, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (branch4): Sequential(
#       (0): MaxPool2d(kernel_size=3, stride=1, padding=1, dilation=1, ceil_mode=True)
#       (1): BasicConv2d(
#         (conv): Conv2d(256, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn): BatchNorm2d(64, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#   )
#   (maxpool3): MaxPool2d(kernel_size=3, stride=2, padding=0, dilation=1, ceil_mode=True)
#   (inception4a): Inception(
#     (branch1): BasicConv2d(
#       (conv): Conv2d(480, 192, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn): BatchNorm2d(192, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (branch2): Sequential(
#       (0): BasicConv2d(
#         (conv): Conv2d(480, 96, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn): BatchNorm2d(96, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#       )
#       (1): BasicConv2d(
#         (conv): Conv2d(96, 208, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn): BatchNorm2d(208, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (branch3): Sequential(
#       (0): BasicConv2d(
#         (conv): Conv2d(480, 16, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn): BatchNorm2d(16, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#       )
#       (1): BasicConv2d(
#         (conv): Conv2d(16, 48, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn): BatchNorm2d(48, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (branch4): Sequential(
#       (0): MaxPool2d(kernel_size=3, stride=1, padding=1, dilation=1, ceil_mode=True)
#       (1): BasicConv2d(
#         (conv): Conv2d(480, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn): BatchNorm2d(64, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#   )
#   (inception4b): Inception(
#     (branch1): BasicConv2d(
#       (conv): Conv2d(512, 160, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn): BatchNorm2d(160, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (branch2): Sequential(
#       (0): BasicConv2d(
#         (conv): Conv2d(512, 112, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn): BatchNorm2d(112, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#       )
#       (1): BasicConv2d(
#         (conv): Conv2d(112, 224, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn): BatchNorm2d(224, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (branch3): Sequential(
#       (0): BasicConv2d(
#         (conv): Conv2d(512, 24, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn): BatchNorm2d(24, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#       )
#       (1): BasicConv2d(
#         (conv): Conv2d(24, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn): BatchNorm2d(64, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (branch4): Sequential(
#       (0): MaxPool2d(kernel_size=3, stride=1, padding=1, dilation=1, ceil_mode=True)
#       (1): BasicConv2d(
#         (conv): Conv2d(512, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn): BatchNorm2d(64, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#   )
#   (inception4c): Inception(
#     (branch1): BasicConv2d(
#       (conv): Conv2d(512, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn): BatchNorm2d(128, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (branch2): Sequential(
#       (0): BasicConv2d(
#         (conv): Conv2d(512, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn): BatchNorm2d(128, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#       )
#       (1): BasicConv2d(
#         (conv): Conv2d(128, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn): BatchNorm2d(256, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (branch3): Sequential(
#       (0): BasicConv2d(
#         (conv): Conv2d(512, 24, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn): BatchNorm2d(24, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#       )
#       (1): BasicConv2d(
#         (conv): Conv2d(24, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn): BatchNorm2d(64, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (branch4): Sequential(
#       (0): MaxPool2d(kernel_size=3, stride=1, padding=1, dilation=1, ceil_mode=True)
#       (1): BasicConv2d(
#         (conv): Conv2d(512, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn): BatchNorm2d(64, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#   )
#   (inception4d): Inception(
#     (branch1): BasicConv2d(
#       (conv): Conv2d(512, 112, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn): BatchNorm2d(112, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (branch2): Sequential(
#       (0): BasicConv2d(
#         (conv): Conv2d(512, 144, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn): BatchNorm2d(144, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#       )
#       (1): BasicConv2d(
#         (conv): Conv2d(144, 288, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn): BatchNorm2d(288, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (branch3): Sequential(
#       (0): BasicConv2d(
#         (conv): Conv2d(512, 32, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn): BatchNorm2d(32, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#       )
#       (1): BasicConv2d(
#         (conv): Conv2d(32, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn): BatchNorm2d(64, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (branch4): Sequential(
#       (0): MaxPool2d(kernel_size=3, stride=1, padding=1, dilation=1, ceil_mode=True)
#       (1): BasicConv2d(
#         (conv): Conv2d(512, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn): BatchNorm2d(64, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#   )
#   (inception4e): Inception(
#     (branch1): BasicConv2d(
#       (conv): Conv2d(528, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn): BatchNorm2d(256, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (branch2): Sequential(
#       (0): BasicConv2d(
#         (conv): Conv2d(528, 160, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn): BatchNorm2d(160, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#       )
#       (1): BasicConv2d(
#         (conv): Conv2d(160, 320, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn): BatchNorm2d(320, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (branch3): Sequential(
#       (0): BasicConv2d(
#         (conv): Conv2d(528, 32, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn): BatchNorm2d(32, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#       )
#       (1): BasicConv2d(
#         (conv): Conv2d(32, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn): BatchNorm2d(128, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (branch4): Sequential(
#       (0): MaxPool2d(kernel_size=3, stride=1, padding=1, dilation=1, ceil_mode=True)
#       (1): BasicConv2d(
#         (conv): Conv2d(528, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn): BatchNorm2d(128, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#   )
#   (maxpool4): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=True)
#   (inception5a): Inception(
#     (branch1): BasicConv2d(
#       (conv): Conv2d(832, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn): BatchNorm2d(256, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (branch2): Sequential(
#       (0): BasicConv2d(
#         (conv): Conv2d(832, 160, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn): BatchNorm2d(160, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#       )
#       (1): BasicConv2d(
#         (conv): Conv2d(160, 320, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn): BatchNorm2d(320, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (branch3): Sequential(
#       (0): BasicConv2d(
#         (conv): Conv2d(832, 32, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn): BatchNorm2d(32, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#       )
#       (1): BasicConv2d(
#         (conv): Conv2d(32, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn): BatchNorm2d(128, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (branch4): Sequential(
#       (0): MaxPool2d(kernel_size=3, stride=1, padding=1, dilation=1, ceil_mode=True)
#       (1): BasicConv2d(
#         (conv): Conv2d(832, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn): BatchNorm2d(128, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#   )
#   (inception5b): Inception(
#     (branch1): BasicConv2d(
#       (conv): Conv2d(832, 384, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn): BatchNorm2d(384, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (branch2): Sequential(
#       (0): BasicConv2d(
#         (conv): Conv2d(832, 192, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn): BatchNorm2d(192, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#       )
#       (1): BasicConv2d(
#         (conv): Conv2d(192, 384, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn): BatchNorm2d(384, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (branch3): Sequential(
#       (0): BasicConv2d(
#         (conv): Conv2d(832, 48, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn): BatchNorm2d(48, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#       )
#       (1): BasicConv2d(
#         (conv): Conv2d(48, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn): BatchNorm2d(128, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (branch4): Sequential(
#       (0): MaxPool2d(kernel_size=3, stride=1, padding=1, dilation=1, ceil_mode=True)
#       (1): BasicConv2d(
#         (conv): Conv2d(832, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn): BatchNorm2d(128, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#   )
#   (aux1): None
#   (aux2): None
#   (avgpool): AdaptiveAvgPool2d(output_size=(1, 1))
#   (dropout): Dropout(p=0.2, inplace=False)
#   (fc): Linear(in_features=1024, out_features=1000, bias=True)
# )

# %%
import torch.nn as nn
n_classes = 4
# add on our own custom classifier
model.fc = nn.Sequential(
                      nn.Linear(1024, 1000), 
                      nn.ReLU(), 
                      nn.Dropout(0.4),
                      nn.Linear(1000, n_classes),                   
                      nn.LogSoftmax(dim=1))

# %%
model.eval()
# Out:
# GoogLeNet(
#   (conv1): BasicConv2d(
#     (conv): Conv2d(3, 64, kernel_size=(7, 7), stride=(2, 2), padding=(3, 3), bias=False)
#     (bn): BatchNorm2d(64, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#   )
#   (maxpool1): MaxPool2d(kernel_size=3, stride=2, padding=0, dilation=1, ceil_mode=True)
#   (conv2): BasicConv2d(
#     (conv): Conv2d(64, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#     (bn): BatchNorm2d(64, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#   )
#   (conv3): BasicConv2d(
#     (conv): Conv2d(64, 192, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#     (bn): BatchNorm2d(192, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#   )
#   (maxpool2): MaxPool2d(kernel_size=3, stride=2, padding=0, dilation=1, ceil_mode=True)
#   (inception3a): Inception(
#     (branch1): BasicConv2d(
#       (conv): Conv2d(192, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn): BatchNorm2d(64, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (branch2): Sequential(
#       (0): BasicConv2d(
#         (conv): Conv2d(192, 96, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn): BatchNorm2d(96, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#       )
#       (1): BasicConv2d(
#         (conv): Conv2d(96, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn): BatchNorm2d(128, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (branch3): Sequential(
#       (0): BasicConv2d(
#         (conv): Conv2d(192, 16, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn): BatchNorm2d(16, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#       )
#       (1): BasicConv2d(
#         (conv): Conv2d(16, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn): BatchNorm2d(32, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (branch4): Sequential(
#       (0): MaxPool2d(kernel_size=3, stride=1, padding=1, dilation=1, ceil_mode=True)
#       (1): BasicConv2d(
#         (conv): Conv2d(192, 32, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn): BatchNorm2d(32, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#   )
#   (inception3b): Inception(
#     (branch1): BasicConv2d(
#       (conv): Conv2d(256, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn): BatchNorm2d(128, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (branch2): Sequential(
#       (0): BasicConv2d(
#         (conv): Conv2d(256, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn): BatchNorm2d(128, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#       )
#       (1): BasicConv2d(
#         (conv): Conv2d(128, 192, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn): BatchNorm2d(192, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (branch3): Sequential(
#       (0): BasicConv2d(
#         (conv): Conv2d(256, 32, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn): BatchNorm2d(32, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#       )
#       (1): BasicConv2d(
#         (conv): Conv2d(32, 96, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn): BatchNorm2d(96, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (branch4): Sequential(
#       (0): MaxPool2d(kernel_size=3, stride=1, padding=1, dilation=1, ceil_mode=True)
#       (1): BasicConv2d(
#         (conv): Conv2d(256, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn): BatchNorm2d(64, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#   )
#   (maxpool3): MaxPool2d(kernel_size=3, stride=2, padding=0, dilation=1, ceil_mode=True)
#   (inception4a): Inception(
#     (branch1): BasicConv2d(
#       (conv): Conv2d(480, 192, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn): BatchNorm2d(192, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (branch2): Sequential(
#       (0): BasicConv2d(
#         (conv): Conv2d(480, 96, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn): BatchNorm2d(96, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#       )
#       (1): BasicConv2d(
#         (conv): Conv2d(96, 208, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn): BatchNorm2d(208, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (branch3): Sequential(
#       (0): BasicConv2d(
#         (conv): Conv2d(480, 16, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn): BatchNorm2d(16, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#       )
#       (1): BasicConv2d(
#         (conv): Conv2d(16, 48, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn): BatchNorm2d(48, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (branch4): Sequential(
#       (0): MaxPool2d(kernel_size=3, stride=1, padding=1, dilation=1, ceil_mode=True)
#       (1): BasicConv2d(
#         (conv): Conv2d(480, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn): BatchNorm2d(64, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#   )
#   (inception4b): Inception(
#     (branch1): BasicConv2d(
#       (conv): Conv2d(512, 160, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn): BatchNorm2d(160, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (branch2): Sequential(
#       (0): BasicConv2d(
#         (conv): Conv2d(512, 112, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn): BatchNorm2d(112, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#       )
#       (1): BasicConv2d(
#         (conv): Conv2d(112, 224, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn): BatchNorm2d(224, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (branch3): Sequential(
#       (0): BasicConv2d(
#         (conv): Conv2d(512, 24, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn): BatchNorm2d(24, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#       )
#       (1): BasicConv2d(
#         (conv): Conv2d(24, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn): BatchNorm2d(64, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (branch4): Sequential(
#       (0): MaxPool2d(kernel_size=3, stride=1, padding=1, dilation=1, ceil_mode=True)
#       (1): BasicConv2d(
#         (conv): Conv2d(512, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn): BatchNorm2d(64, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#   )
#   (inception4c): Inception(
#     (branch1): BasicConv2d(
#       (conv): Conv2d(512, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn): BatchNorm2d(128, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (branch2): Sequential(
#       (0): BasicConv2d(
#         (conv): Conv2d(512, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn): BatchNorm2d(128, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#       )
#       (1): BasicConv2d(
#         (conv): Conv2d(128, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn): BatchNorm2d(256, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (branch3): Sequential(
#       (0): BasicConv2d(
#         (conv): Conv2d(512, 24, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn): BatchNorm2d(24, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#       )
#       (1): BasicConv2d(
#         (conv): Conv2d(24, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn): BatchNorm2d(64, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (branch4): Sequential(
#       (0): MaxPool2d(kernel_size=3, stride=1, padding=1, dilation=1, ceil_mode=True)
#       (1): BasicConv2d(
#         (conv): Conv2d(512, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn): BatchNorm2d(64, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#   )
#   (inception4d): Inception(
#     (branch1): BasicConv2d(
#       (conv): Conv2d(512, 112, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn): BatchNorm2d(112, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (branch2): Sequential(
#       (0): BasicConv2d(
#         (conv): Conv2d(512, 144, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn): BatchNorm2d(144, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#       )
#       (1): BasicConv2d(
#         (conv): Conv2d(144, 288, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn): BatchNorm2d(288, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (branch3): Sequential(
#       (0): BasicConv2d(
#         (conv): Conv2d(512, 32, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn): BatchNorm2d(32, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#       )
#       (1): BasicConv2d(
#         (conv): Conv2d(32, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn): BatchNorm2d(64, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (branch4): Sequential(
#       (0): MaxPool2d(kernel_size=3, stride=1, padding=1, dilation=1, ceil_mode=True)
#       (1): BasicConv2d(
#         (conv): Conv2d(512, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn): BatchNorm2d(64, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#   )
#   (inception4e): Inception(
#     (branch1): BasicConv2d(
#       (conv): Conv2d(528, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn): BatchNorm2d(256, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (branch2): Sequential(
#       (0): BasicConv2d(
#         (conv): Conv2d(528, 160, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn): BatchNorm2d(160, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#       )
#       (1): BasicConv2d(
#         (conv): Conv2d(160, 320, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn): BatchNorm2d(320, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (branch3): Sequential(
#       (0): BasicConv2d(
#         (conv): Conv2d(528, 32, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn): BatchNorm2d(32, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#       )
#       (1): BasicConv2d(
#         (conv): Conv2d(32, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn): BatchNorm2d(128, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (branch4): Sequential(
#       (0): MaxPool2d(kernel_size=3, stride=1, padding=1, dilation=1, ceil_mode=True)
#       (1): BasicConv2d(
#         (conv): Conv2d(528, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn): BatchNorm2d(128, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#   )
#   (maxpool4): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=True)
#   (inception5a): Inception(
#     (branch1): BasicConv2d(
#       (conv): Conv2d(832, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn): BatchNorm2d(256, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (branch2): Sequential(
#       (0): BasicConv2d(
#         (conv): Conv2d(832, 160, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn): BatchNorm2d(160, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#       )
#       (1): BasicConv2d(
#         (conv): Conv2d(160, 320, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn): BatchNorm2d(320, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (branch3): Sequential(
#       (0): BasicConv2d(
#         (conv): Conv2d(832, 32, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn): BatchNorm2d(32, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#       )
#       (1): BasicConv2d(
#         (conv): Conv2d(32, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn): BatchNorm2d(128, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (branch4): Sequential(
#       (0): MaxPool2d(kernel_size=3, stride=1, padding=1, dilation=1, ceil_mode=True)
#       (1): BasicConv2d(
#         (conv): Conv2d(832, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn): BatchNorm2d(128, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#   )
#   (inception5b): Inception(
#     (branch1): BasicConv2d(
#       (conv): Conv2d(832, 384, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn): BatchNorm2d(384, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (branch2): Sequential(
#       (0): BasicConv2d(
#         (conv): Conv2d(832, 192, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn): BatchNorm2d(192, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#       )
#       (1): BasicConv2d(
#         (conv): Conv2d(192, 384, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn): BatchNorm2d(384, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (branch3): Sequential(
#       (0): BasicConv2d(
#         (conv): Conv2d(832, 48, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn): BatchNorm2d(48, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#       )
#       (1): BasicConv2d(
#         (conv): Conv2d(48, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn): BatchNorm2d(128, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (branch4): Sequential(
#       (0): MaxPool2d(kernel_size=3, stride=1, padding=1, dilation=1, ceil_mode=True)
#       (1): BasicConv2d(
#         (conv): Conv2d(832, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn): BatchNorm2d(128, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#   )
#   (aux1): None
#   (aux2): None
#   (avgpool): AdaptiveAvgPool2d(output_size=(1, 1))
#   (dropout): Dropout(p=0.2, inplace=False)
#   (fc): Sequential(
#     (0): Linear(in_features=1024, out_features=1000, bias=True)
#     (1): ReLU()
#     (2): Dropout(p=0.4, inplace=False)
#     (3): Linear(in_features=1000, out_features=4, bias=True)
#     (4): LogSoftmax(dim=1)
#   )
# )

# %%
# Find total parameters and trainable parameters
total_params = sum(p.numel() for p in model.parameters())
print(f'{total_params:,} total parameters.')
total_trainable_params = sum(
    p.numel() for p in model.parameters() if p.requires_grad)
print(f'{total_trainable_params:,} training parameters.')
# Out:
# 6,628,908 total parameters.
# 1,029,004 training parameters.

# %%
# Move to gpu
model = model.to(device)
# Distribute across 2 gpus
model = nn.DataParallel(model)
print(device)
# Out:
# cuda

# %%
from torch import optim

# Loss and optimizer
criteration = nn.NLLLoss()
criteration = criteration.to(device)
optimizer = optim.Adam(model.parameters())

# %%
total_step = len(train_loader)
loss_list = []
acc_list = []
n_epochs = 20
for epoch in range(n_epochs):
  for i, (images, targets) in enumerate(train_loader):
    images = images.to(device)
    targets = targets.to(device)
    # Generate predictions
    outputs = model(images)
    outputs = outputs.to(device)
    # Calculate loss
    loss = criteration(outputs, targets)
    loss_list.append(loss.item())
    # Backprop and perform Adam optimisation
    optimizer.zero_grad()
    # Backpropagation
    loss.requres_grad = False
    loss.backward()
    # Update model parameters
    optimizer.step()
    
    # Track the accuracy
    total = targets.size(0)
    _, predicted = torch.max(outputs.data, 1)
    correct = (predicted == targets).sum().item()
    acc_list.append(correct / total)
    print("Training")
    print('Epoch [{}/{}], Step [{}/{}], Loss: {:.4f}, Accuracy: {:.2f}%'.format(epoch + 1, n_epochs, i + 1, total_step, loss.item(),(correct / total) * 100))
# Out:
# Training
# Epoch [1/20], Step [1/11], Loss: 1.3842, Accuracy: 31.25%
# Training
# Epoch [1/20], Step [2/11], Loss: 1.6772, Accuracy: 28.12%
# Training
# Epoch [1/20], Step [3/11], Loss: 1.4040, Accuracy: 21.88%
# Training
# Epoch [1/20], Step [4/11], Loss: 1.3980, Accuracy: 12.50%
# Training
# Epoch [1/20], Step [5/11], Loss: 1.3284, Accuracy: 28.12%
# Training
# Epoch [1/20], Step [6/11], Loss: 1.2536, Accuracy: 46.88%
# Training
# Epoch [1/20], Step [7/11], Loss: 1.2694, Accuracy: 28.12%
# Training
# Epoch [1/20], Step [8/11], Loss: 1.1317, Accuracy: 53.12%
# Training
# Epoch [1/20], Step [9/11], Loss: 1.0882, Accuracy: 62.50%
# Training
# Epoch [1/20], Step [10/11], Loss: 1.1126, Accuracy: 46.88%
# Training
# Epoch [1/20], Step [11/11], Loss: 1.4485, Accuracy: 0.00%
# Training
# Epoch [2/20], Step [1/11], Loss: 0.9872, Accuracy: 56.25%
# Training
# Epoch [2/20], Step [2/11], Loss: 1.0054, Accuracy: 62.50%
# Training
# Epoch [2/20], Step [3/11], Loss: 1.1566, Accuracy: 31.25%
# Training
# Epoch [2/20], Step [4/11], Loss: 1.1501, Accuracy: 34.38%
# Training
# Epoch [2/20], Step [5/11], Loss: 1.1465, Accuracy: 50.00%
# Training
# Epoch [2/20], Step [6/11], Loss: 0.9793, Accuracy: 59.38%
# Training
# Epoch [2/20], Step [7/11], Loss: 0.9592, Accuracy: 71.88%
# Training
# Epoch [2/20], Step [8/11], Loss: 1.0101, Accuracy: 53.12%
# Training
# Epoch [2/20], Step [9/11], Loss: 0.8964, Accuracy: 62.50%
# Training
# Epoch [2/20], Step [10/11], Loss: 0.9949, Accuracy: 53.12%
# Training
# Epoch [2/20], Step [11/11], Loss: 0.6033, Accuracy: 100.00%
# Training
# Epoch [3/20], Step [1/11], Loss: 1.0343, Accuracy: 56.25%
# Training
# Epoch [3/20], Step [2/11], Loss: 0.8088, Accuracy: 65.62%
# Training
# Epoch [3/20], Step [3/11], Loss: 1.0079, Accuracy: 62.50%
# Training
# Epoch [3/20], Step [4/11], Loss: 0.8929, Accuracy: 56.25%
# Training
# Epoch [3/20], Step [5/11], Loss: 0.7043, Accuracy: 71.88%
# Training
# Epoch [3/20], Step [6/11], Loss: 0.7376, Accuracy: 68.75%
# Training
# Epoch [3/20], Step [7/11], Loss: 0.6938, Accuracy: 68.75%
# Training
# Epoch [3/20], Step [8/11], Loss: 0.8916, Accuracy: 56.25%
# Training
# Epoch [3/20], Step [9/11], Loss: 0.9197, Accuracy: 62.50%
# Training
# Epoch [3/20], Step [10/11], Loss: 0.9131, Accuracy: 56.25%
# Training
# Epoch [3/20], Step [11/11], Loss: 0.4568, Accuracy: 100.00%
# Training
# Epoch [4/20], Step [1/11], Loss: 0.9116, Accuracy: 62.50%
# Training
# Epoch [4/20], Step [2/11], Loss: 0.8450, Accuracy: 56.25%
# Training
# Epoch [4/20], Step [3/11], Loss: 0.8735, Accuracy: 59.38%
# Training
# Epoch [4/20], Step [4/11], Loss: 0.8811, Accuracy: 56.25%
# Training
# Epoch [4/20], Step [5/11], Loss: 0.6746, Accuracy: 75.00%
# Training
# Epoch [4/20], Step [6/11], Loss: 0.6751, Accuracy: 71.88%
# Training
# Epoch [4/20], Step [7/11], Loss: 0.8617, Accuracy: 65.62%
# Training
# Epoch [4/20], Step [8/11], Loss: 0.5863, Accuracy: 87.50%
# Training
# Epoch [4/20], Step [9/11], Loss: 0.7245, Accuracy: 78.12%
# Training
# Epoch [4/20], Step [10/11], Loss: 0.6652, Accuracy: 71.88%
# Training
# Epoch [4/20], Step [11/11], Loss: 0.0328, Accuracy: 100.00%
# Training
# Epoch [5/20], Step [1/11], Loss: 0.7211, Accuracy: 59.38%
# Training
# Epoch [5/20], Step [2/11], Loss: 0.4907, Accuracy: 84.38%
# Training
# Epoch [5/20], Step [3/11], Loss: 0.6110, Accuracy: 75.00%
# Training
# Epoch [5/20], Step [4/11], Loss: 0.8196, Accuracy: 59.38%
# Training
# Epoch [5/20], Step [5/11], Loss: 0.3949, Accuracy: 93.75%
# Training
# Epoch [5/20], Step [6/11], Loss: 0.7307, Accuracy: 71.88%
# Training
# Epoch [5/20], Step [7/11], Loss: 0.7009, Accuracy: 68.75%
# Training
# Epoch [5/20], Step [8/11], Loss: 0.7417, Accuracy: 65.62%
# Training
# Epoch [5/20], Step [9/11], Loss: 0.5241, Accuracy: 84.38%
# Training
# Epoch [5/20], Step [10/11], Loss: 0.7379, Accuracy: 71.88%
# Training
# Epoch [5/20], Step [11/11], Loss: 0.0071, Accuracy: 100.00%
# Training
# Epoch [6/20], Step [1/11], Loss: 0.5964, Accuracy: 78.12%
# Training
# Epoch [6/20], Step [2/11], Loss: 0.4873, Accuracy: 90.62%
# Training
# Epoch [6/20], Step [3/11], Loss: 0.5252, Accuracy: 75.00%
# Training
# Epoch [6/20], Step [4/11], Loss: 0.8836, Accuracy: 53.12%
# Training
# Epoch [6/20], Step [5/11], Loss: 0.5914, Accuracy: 75.00%
# Training
# Epoch [6/20], Step [6/11], Loss: 0.5576, Accuracy: 81.25%
# Training
# Epoch [6/20], Step [7/11], Loss: 0.5299, Accuracy: 84.38%
# Training
# Epoch [6/20], Step [8/11], Loss: 0.6118, Accuracy: 71.88%
# Training
# Epoch [6/20], Step [9/11], Loss: 0.5484, Accuracy: 84.38%
# Training
# Epoch [6/20], Step [10/11], Loss: 0.7254, Accuracy: 71.88%
# Training
# Epoch [6/20], Step [11/11], Loss: 0.4752, Accuracy: 100.00%
# Training
# Epoch [7/20], Step [1/11], Loss: 0.8632, Accuracy: 59.38%
# Training
# Epoch [7/20], Step [2/11], Loss: 0.5343, Accuracy: 78.12%
# Training
# Epoch [7/20], Step [3/11], Loss: 0.4949, Accuracy: 78.12%
# Training
# Epoch [7/20], Step [4/11], Loss: 0.4962, Accuracy: 81.25%
# Training
# Epoch [7/20], Step [5/11], Loss: 0.5819, Accuracy: 81.25%
# Training
# Epoch [7/20], Step [6/11], Loss: 0.5363, Accuracy: 78.12%
# Training
# Epoch [7/20], Step [7/11], Loss: 0.4961, Accuracy: 78.12%
# Training
# Epoch [7/20], Step [8/11], Loss: 0.4858, Accuracy: 87.50%
# Training
# Epoch [7/20], Step [9/11], Loss: 0.5748, Accuracy: 81.25%
# Training
# Epoch [7/20], Step [10/11], Loss: 0.6632, Accuracy: 75.00%
# Training
# Epoch [7/20], Step [11/11], Loss: 0.6418, Accuracy: 100.00%
# Training
# Epoch [8/20], Step [1/11], Loss: 0.6101, Accuracy: 78.12%
# Training
# Epoch [8/20], Step [2/11], Loss: 0.7202, Accuracy: 62.50%
# Training
# Epoch [8/20], Step [3/11], Loss: 0.8776, Accuracy: 56.25%
# Training
# Epoch [8/20], Step [4/11], Loss: 0.7184, Accuracy: 68.75%
# Training
# Epoch [8/20], Step [5/11], Loss: 0.5114, Accuracy: 81.25%
# Training
# Epoch [8/20], Step [6/11], Loss: 0.4603, Accuracy: 87.50%
# Training
# Epoch [8/20], Step [7/11], Loss: 0.5160, Accuracy: 84.38%
# Training
# Epoch [8/20], Step [8/11], Loss: 0.3621, Accuracy: 87.50%
# Training
# Epoch [8/20], Step [9/11], Loss: 0.5935, Accuracy: 71.88%
# Training
# Epoch [8/20], Step [10/11], Loss: 0.5886, Accuracy: 71.88%
# Training
# Epoch [8/20], Step [11/11], Loss: 0.0044, Accuracy: 100.00%
# Training
# Epoch [9/20], Step [1/11], Loss: 0.5957, Accuracy: 75.00%
# Training
# Epoch [9/20], Step [2/11], Loss: 0.6538, Accuracy: 78.12%
# Training
# Epoch [9/20], Step [3/11], Loss: 0.4946, Accuracy: 78.12%
# Training
# Epoch [9/20], Step [4/11], Loss: 0.6111, Accuracy: 81.25%
# Training
# Epoch [9/20], Step [5/11], Loss: 0.3226, Accuracy: 90.62%
# Training
# Epoch [9/20], Step [6/11], Loss: 0.4676, Accuracy: 84.38%
# Training
# Epoch [9/20], Step [7/11], Loss: 0.4735, Accuracy: 81.25%
# Training
# Epoch [9/20], Step [8/11], Loss: 0.5385, Accuracy: 78.12%
# Training
# Epoch [9/20], Step [9/11], Loss: 0.5472, Accuracy: 81.25%
# Training
# Epoch [9/20], Step [10/11], Loss: 0.5975, Accuracy: 71.88%
# Training
# Epoch [9/20], Step [11/11], Loss: 0.4131, Accuracy: 100.00%
# Training
# Epoch [10/20], Step [1/11], Loss: 0.4892, Accuracy: 84.38%
# Training
# Epoch [10/20], Step [2/11], Loss: 0.7283, Accuracy: 78.12%
# Training
# Epoch [10/20], Step [3/11], Loss: 0.4469, Accuracy: 81.25%
# Training
# Epoch [10/20], Step [4/11], Loss: 0.3994, Accuracy: 81.25%
# Training
# Epoch [10/20], Step [5/11], Loss: 0.3206, Accuracy: 87.50%
# Training
# Epoch [10/20], Step [6/11], Loss: 0.5387, Accuracy: 71.88%
# Training
# Epoch [10/20], Step [7/11], Loss: 0.5290, Accuracy: 84.38%
# Training
# Epoch [10/20], Step [8/11], Loss: 0.3479, Accuracy: 90.62%
# Training
# Epoch [10/20], Step [9/11], Loss: 0.5943, Accuracy: 62.50%
# Training
# Epoch [10/20], Step [10/11], Loss: 0.4100, Accuracy: 93.75%
# Training
# Epoch [10/20], Step [11/11], Loss: 0.0623, Accuracy: 100.00%
# Training
# Epoch [11/20], Step [1/11], Loss: 0.4285, Accuracy: 90.62%
# Training
# Epoch [11/20], Step [2/11], Loss: 0.3952, Accuracy: 87.50%
# Training
# Epoch [11/20], Step [3/11], Loss: 0.5048, Accuracy: 71.88%
# Training
# Epoch [11/20], Step [4/11], Loss: 0.3706, Accuracy: 87.50%
# Training
# Epoch [11/20], Step [5/11], Loss: 0.5529, Accuracy: 78.12%
# Training
# Epoch [11/20], Step [6/11], Loss: 0.3580, Accuracy: 87.50%
# Training
# Epoch [11/20], Step [7/11], Loss: 0.4931, Accuracy: 78.12%
# Training
# Epoch [11/20], Step [8/11], Loss: 0.4602, Accuracy: 84.38%
# Training
# Epoch [11/20], Step [9/11], Loss: 0.2364, Accuracy: 90.62%
# Training
# Epoch [11/20], Step [10/11], Loss: 0.3763, Accuracy: 84.38%
# Training
# Epoch [11/20], Step [11/11], Loss: 0.6272, Accuracy: 100.00%
# Training
# Epoch [12/20], Step [1/11], Loss: 0.6153, Accuracy: 75.00%
# Training
# Epoch [12/20], Step [2/11], Loss: 0.2811, Accuracy: 84.38%
# Training
# Epoch [12/20], Step [3/11], Loss: 0.7483, Accuracy: 62.50%
# Training
# Epoch [12/20], Step [4/11], Loss: 0.6718, Accuracy: 68.75%
# Training
# Epoch [12/20], Step [5/11], Loss: 0.3412, Accuracy: 87.50%
# Training
# Epoch [12/20], Step [6/11], Loss: 0.3922, Accuracy: 87.50%
# Training
# Epoch [12/20], Step [7/11], Loss: 0.5061, Accuracy: 78.12%
# Training
# Epoch [12/20], Step [8/11], Loss: 0.4564, Accuracy: 87.50%
# Training
# Epoch [12/20], Step [9/11], Loss: 0.5178, Accuracy: 75.00%
# Training
# Epoch [12/20], Step [10/11], Loss: 0.3728, Accuracy: 84.38%
# Training
# Epoch [12/20], Step [11/11], Loss: 0.0443, Accuracy: 100.00%
# Training
# Epoch [13/20], Step [1/11], Loss: 0.4414, Accuracy: 81.25%
# Training
# Epoch [13/20], Step [2/11], Loss: 0.2428, Accuracy: 96.88%
# Training
# Epoch [13/20], Step [3/11], Loss: 0.3749, Accuracy: 84.38%
# Training
# Epoch [13/20], Step [4/11], Loss: 0.3522, Accuracy: 84.38%
# Training
# Epoch [13/20], Step [5/11], Loss: 0.4335, Accuracy: 84.38%
# Training
# Epoch [13/20], Step [6/11], Loss: 0.4851, Accuracy: 78.12%
# Training
# Epoch [13/20], Step [7/11], Loss: 0.3134, Accuracy: 87.50%
# Training
# Epoch [13/20], Step [8/11], Loss: 0.5868, Accuracy: 78.12%
# Training
# Epoch [13/20], Step [9/11], Loss: 0.3599, Accuracy: 84.38%
# Training
# Epoch [13/20], Step [10/11], Loss: 0.3927, Accuracy: 84.38%
# Training
# Epoch [13/20], Step [11/11], Loss: 1.9694, Accuracy: 0.00%
# Training
# Epoch [14/20], Step [1/11], Loss: 0.7209, Accuracy: 71.88%
# Training
# Epoch [14/20], Step [2/11], Loss: 0.6002, Accuracy: 71.88%
# Training
# Epoch [14/20], Step [3/11], Loss: 1.0287, Accuracy: 59.38%
# Training
# Epoch [14/20], Step [4/11], Loss: 0.8876, Accuracy: 62.50%
# Training
# Epoch [14/20], Step [5/11], Loss: 0.7223, Accuracy: 71.88%
# Training
# Epoch [14/20], Step [6/11], Loss: 0.4152, Accuracy: 87.50%
# Training
# Epoch [14/20], Step [7/11], Loss: 0.4847, Accuracy: 81.25%
# Training
# Epoch [14/20], Step [8/11], Loss: 0.6155, Accuracy: 75.00%
# Training
# Epoch [14/20], Step [9/11], Loss: 0.6969, Accuracy: 68.75%
# Training
# Epoch [14/20], Step [10/11], Loss: 0.6108, Accuracy: 71.88%
# Training
# Epoch [14/20], Step [11/11], Loss: 0.5235, Accuracy: 100.00%
# Training
# Epoch [15/20], Step [1/11], Loss: 1.0653, Accuracy: 59.38%
# Training
# Epoch [15/20], Step [2/11], Loss: 1.0323, Accuracy: 59.38%
# Training
# Epoch [15/20], Step [3/11], Loss: 0.9095, Accuracy: 62.50%
# Training
# Epoch [15/20], Step [4/11], Loss: 0.5347, Accuracy: 78.12%
# Training
# Epoch [15/20], Step [5/11], Loss: 0.3750, Accuracy: 90.62%
# Training
# Epoch [15/20], Step [6/11], Loss: 0.4526, Accuracy: 84.38%
# Training
# Epoch [15/20], Step [7/11], Loss: 0.4306, Accuracy: 84.38%
# Training
# Epoch [15/20], Step [8/11], Loss: 0.3427, Accuracy: 90.62%
# Training
# Epoch [15/20], Step [9/11], Loss: 0.9741, Accuracy: 65.62%
# Training
# Epoch [15/20], Step [10/11], Loss: 0.4043, Accuracy: 84.38%
# Training
# Epoch [15/20], Step [11/11], Loss: 0.1123, Accuracy: 100.00%
# Training
# Epoch [16/20], Step [1/11], Loss: 0.4548, Accuracy: 81.25%
# Training
# Epoch [16/20], Step [2/11], Loss: 0.3224, Accuracy: 90.62%
# Training
# Epoch [16/20], Step [3/11], Loss: 0.2745, Accuracy: 90.62%
# Training
# Epoch [16/20], Step [4/11], Loss: 0.4704, Accuracy: 84.38%
# Training
# Epoch [16/20], Step [5/11], Loss: 0.5085, Accuracy: 75.00%
# Training
# Epoch [16/20], Step [6/11], Loss: 0.4220, Accuracy: 84.38%
# Training
# Epoch [16/20], Step [7/11], Loss: 0.6824, Accuracy: 62.50%
# Training
# Epoch [16/20], Step [8/11], Loss: 0.3270, Accuracy: 81.25%
# Training
# Epoch [16/20], Step [9/11], Loss: 0.3058, Accuracy: 90.62%
# Training
# Epoch [16/20], Step [10/11], Loss: 0.6037, Accuracy: 75.00%
# Training
# Epoch [16/20], Step [11/11], Loss: 0.1524, Accuracy: 100.00%
# Training
# Epoch [17/20], Step [1/11], Loss: 0.4283, Accuracy: 81.25%
# Training
# Epoch [17/20], Step [2/11], Loss: 0.3955, Accuracy: 90.62%
# Training
# Epoch [17/20], Step [3/11], Loss: 0.4030, Accuracy: 84.38%
# Training
# Epoch [17/20], Step [4/11], Loss: 0.3611, Accuracy: 81.25%
# Training
# Epoch [17/20], Step [5/11], Loss: 0.4106, Accuracy: 81.25%
# Training
# Epoch [17/20], Step [6/11], Loss: 0.2798, Accuracy: 93.75%
# Training
# Epoch [17/20], Step [7/11], Loss: 0.2944, Accuracy: 87.50%
# Training
# Epoch [17/20], Step [8/11], Loss: 0.4187, Accuracy: 78.12%
# Training
# Epoch [17/20], Step [9/11], Loss: 0.2493, Accuracy: 96.88%
# Training
# Epoch [17/20], Step [10/11], Loss: 0.5208, Accuracy: 81.25%
# Training
# Epoch [17/20], Step [11/11], Loss: 0.0336, Accuracy: 100.00%
# Training
# Epoch [18/20], Step [1/11], Loss: 0.3745, Accuracy: 84.38%
# Training
# Epoch [18/20], Step [2/11], Loss: 0.5157, Accuracy: 81.25%
# Training
# Epoch [18/20], Step [3/11], Loss: 0.2643, Accuracy: 93.75%
# Training
# Epoch [18/20], Step [4/11], Loss: 0.2676, Accuracy: 90.62%
# Training
# Epoch [18/20], Step [5/11], Loss: 0.3247, Accuracy: 90.62%
# Training
# Epoch [18/20], Step [6/11], Loss: 0.4934, Accuracy: 75.00%
# Training
# Epoch [18/20], Step [7/11], Loss: 0.2048, Accuracy: 93.75%
# Training
# Epoch [18/20], Step [8/11], Loss: 0.2723, Accuracy: 93.75%
# Training
# Epoch [18/20], Step [9/11], Loss: 0.4248, Accuracy: 84.38%
# Training
# Epoch [18/20], Step [10/11], Loss: 0.3814, Accuracy: 84.38%
# Training
# Epoch [18/20], Step [11/11], Loss: 0.1014, Accuracy: 100.00%
# Training
# Epoch [19/20], Step [1/11], Loss: 0.4299, Accuracy: 84.38%
# Training
# Epoch [19/20], Step [2/11], Loss: 0.4268, Accuracy: 87.50%
# Training
# Epoch [19/20], Step [3/11], Loss: 0.3522, Accuracy: 81.25%
# Training
# Epoch [19/20], Step [4/11], Loss: 0.4314, Accuracy: 87.50%
# Training
# Epoch [19/20], Step [5/11], Loss: 0.2222, Accuracy: 90.62%
# Training
# Epoch [19/20], Step [6/11], Loss: 0.2311, Accuracy: 90.62%
# Training
# Epoch [19/20], Step [7/11], Loss: 0.3560, Accuracy: 84.38%
# Training
# Epoch [19/20], Step [8/11], Loss: 0.5784, Accuracy: 78.12%
# Training
# Epoch [19/20], Step [9/11], Loss: 0.3837, Accuracy: 81.25%
# Training
# Epoch [19/20], Step [10/11], Loss: 0.2950, Accuracy: 90.62%
# Training
# Epoch [19/20], Step [11/11], Loss: 0.0492, Accuracy: 100.00%
# Training
# Epoch [20/20], Step [1/11], Loss: 0.4790, Accuracy: 81.25%
# Training
# Epoch [20/20], Step [2/11], Loss: 0.3254, Accuracy: 93.75%
# Training
# Epoch [20/20], Step [3/11], Loss: 0.2273, Accuracy: 90.62%
# Training
# Epoch [20/20], Step [4/11], Loss: 0.3444, Accuracy: 87.50%
# Training
# Epoch [20/20], Step [5/11], Loss: 0.3010, Accuracy: 87.50%
# Training
# Epoch [20/20], Step [6/11], Loss: 0.3119, Accuracy: 87.50%
# Training
# Epoch [20/20], Step [7/11], Loss: 0.4032, Accuracy: 84.38%
# Training
# Epoch [20/20], Step [8/11], Loss: 0.3227, Accuracy: 87.50%
# Training
# Epoch [20/20], Step [9/11], Loss: 0.3288, Accuracy: 84.38%
# Training
# Epoch [20/20], Step [10/11], Loss: 0.2592, Accuracy: 93.75%
# Training
# Epoch [20/20], Step [11/11], Loss: 0.5292, Accuracy: 100.00%

# %%
with torch.no_grad():
    correct = 0
    total = 0
    for images, labels in test_loader:
        images=images.cuda()
        labels=labels.cuda()
        outputs = model(images).cuda()
        _, predicted = torch.max(outputs.data, 1)
        total += labels.size(0)
        correct += (predicted == labels).sum().item()

    print('Test Accuracy#: {} '.format((correct / total) * 100))
# Out:
# Test Accuracy#: 80.0
